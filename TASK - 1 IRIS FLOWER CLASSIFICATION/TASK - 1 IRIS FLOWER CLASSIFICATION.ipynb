# %% [markdown]
# # Iris Flower Classification

# %%
#Dataset Overview
Iris flower dataset with measurements of Sepal Width, Sepal Length, Petal Length, and Petal Width.
Three species: Setosa, Versicolor, and Virginica.
    
#Steps
Import Libraries: Import necessary Python libraries.
Load Dataset: Load the Iris flower dataset.
Summary Statistics: Display summary statistics of the data.
Data Visualization:
-Histograms (Univariate analysis)
-Scatter Plots (Bivariate analysis)
-Pair Plots (Multivariate analysis)
-Correlation Matrix
Data Modeling:
-Train-Test Split
-Decision Tree Classification (ID3 Classifier)
-Confusion Matrix
-Model Accuracy Score
Prediction: Predict the species based on measurements.
Conclusion: Summarize the results and insights from the analysis.

# %%
#import requried libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df = pd.read_csv('IRIS.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Display first 8 and last 6 rows of dataset
print("First eight rows of dataset are: ")
print(df.head(8))
print("\n")
print("Last six rows of dataset are: ")
print(df.tail(6))
# Out:
# First eight rows of dataset are:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
#
#
# Last six rows of dataset are:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# ...

# %%
#Summary statistics of Iris dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#To get no. of rows and columns in the dataset
print("Dimensions of dataset are: ",df.shape)
# Out:
# Dimensions of dataset are:  (150, 6)

# %%
#To get category of each type of species
print("No.of flowers in each species",df.value_counts("Species"))
# Out:
# No.of flowers in each species Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#We will use Matplotlib and Seaborn library for the data visualization.

# %%
#We will construct a count plot to see the count of each species
sns.countplot(x='Species', data=df)
plt.show()

# %%
plt.hist(df['SepalLengthCm'],color='lavender')
plt.title("histogram")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['PetalLengthCm'],color = 'black')
plt.title("histogram")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['SepalWidthCm'],color='green')
plt.title("histogram")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['PetalWidthCm'])
plt.title("histogram")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
sns.swarmplot(x='Species',y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# # Relation between variables(attributes)

# %% [markdown]
# Exploring Iris Flower Attributes
#
# In this analysis, we will explore the relationships between various attributes of Iris flowers, including sepal length, sepal width, petal length, and petal width. Through various plots and visualizations, we aim to understand the connections and patterns within these measurements.

# %%
#We will see the plot between sepallength and sepal width by plotting a Scatter plot between them.
sns.scatterplot(x='SepalLengthCm', y='SepalLengthCm', hue='Species', data=df, )
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
#To display the plot
plt.show()

# %% [markdown]
# Iris-Setosa: Larger sepal width, smaller sepal length.
# Iris-Versicolor: Smaller sepal width and sepal length, intermediate values.
# Iris-Virginica: Larger sepal length, smaller sepal width.
# These observations highlight distinct characteristics in sepal measurements among the three Iris species.

# %%
#We will see the plot between petal length and petal width by plotting a Scatter plot between them.
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, )
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
#To display the plot
plt.show()

# %% [markdown]
# Interpretation:
#
# Iris-Setosa: Smaller petal width and petal length.
# Iris-Versicolor: Measurements between Setosa and Virginica.
# Iris-Virginica: Larger petal length and petal width.
# These insights reveal distinctive petal characteristics among the three Iris species.

# %%
#We will see the plot between sepallength and petal width by plotting a Scatter plot between them.
sns.scatterplot(x='SepalLengthCm', y='PetalWidthCm', hue='Species', data=df, )
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
#To display the plot
plt.show()

# %%
#Multivariate analysis
#Pairplot which shows the pair-wise relation between every attributes
sns.pairplot(df,hue='Species', height=2)

# %%
df.corr(numeric_only=True)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# Visualizing the correlation between the columns using heatmap.
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# # Data Modelling

# %% [raw]
# To evaluate the performance of a machine learning algorithm, we employ the train-test split technique, a crucial step in the process.
# This technique allows us to divide our dataset into two subsets:
# one for training and another for testing.
# To achieve this, we import the train_test_split function from the sklearn.model_selection library. This library provides essential tools for splitting datasets and performing various machine learning tasks, ensuring the robust evaluation of our model's performance.

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ['Species'])
y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.4)
y_test
# Out:
# 76     Iris-versicolor
# 149     Iris-virginica
# 24         Iris-setosa
# 143     Iris-virginica
# 67     Iris-versicolor
# 124     Iris-virginica
# 47         Iris-setosa
# 97     Iris-versicolor
# 36         Iris-setosa
# 88     Iris-versicolor
# 130     Iris-virginica
# 6          Iris-setosa
# 73     Iris-versicolor
# 114     Iris-virginica
# 57     Iris-versicolor
# 107     Iris-virginica
# 69     Iris-versicolor
# 53     Iris-versicolor
# 21         Iris-setosa
# 85     Iris-versicolor
# 146     Iris-virginica
# 121     Iris-virginica
# 117     Iris-virginica
# 17         Iris-setosa
# 64     Iris-versicolor
# 136     Iris-virginica
# 38         Iris-setosa
# 14         Iris-setosa
# 79     Iris-versicolor
# 39         Iris-setosa
# 19         Iris-setosa
# 15         Iris-setosa
# 34         Iris-setosa
# 92     Iris-versicolor
# 125     Iris-virginica
# 98     Iris-versicolor
# 37         Iris-setosa
# 101     Iris-virginica
# 134     Iris-virginica
# 147     Iris-virginica
# ...

# %% [markdown]
# # Decision Tree : ID3 decision tree classifier

# %% [markdown]
# The ID3 algorithm, short for Iterative Dichotomiser 3, derives its name from its iterative and dichotomizing approach. In this algorithm, features are repeatedly divided into two or more groups at each step, forming a decision tree. It is primarily employed for classification tasks, particularly with datasets containing nominal features, where the goal is to categorize data into distinct classes or categories.

# %%
#Importing library foe decision classifier
from sklearn.tree import DecisionTreeClassifier
id3=DecisionTreeClassifier(criterion='entropy')
#Fit the data
k=id3.fit(x_train,y_train)
#predict the data
y_pred=id3.predict(x_test)
print(y_pred)
# Out:
# ['Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
# ...

# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# The confusion matrix serves as a critical tool for assessing the performance of classification models when applied to a specific test dataset. This evaluation can only be conducted when the actual values for the test data are available. The matrix itself is straightforward to interpret, although some of the associated terminology can be perplexing. Essentially, it presents the model's performance errors in a matrix format, earning it the alternative name of an error matrix.

# %%
#Confusion matrix 
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_pred,y_test)
plt.figure(figsize=(10,8))
sns.heatmap(cm,annot=True)
plt.xlabel('predicted-y')
plt.ylabel('actual-y')
plt.show()

# %% [markdown]
# The model's accuracy score is a reflection of its capacity to accurately predict both positive and negative outcomes among all predictions. Mathematically, it signifies the ratio of the sum of true positives and true negatives to the total number of predictions made:
#
# Accuracy Score = (TP + TN) / (TP + FN + TN + FP)
#
# The accuracy score is calculated by comparing the predicted output value to the actual test value. On the other hand, the model's score is determined by examining the relationship between the output and input values during testing.

# %%
#Accuracy score and model score
print(classification_report(y_pred,y_test))
print('accuracy-score',accuracy_score(y_pred,y_test))
print('Model score',id3.score(x_test,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        21
# Iris-versicolor       0.94      1.00      0.97        17
#  Iris-virginica       1.00      0.95      0.98        22
#
#        accuracy                           0.98        60
#       macro avg       0.98      0.98      0.98        60
#    weighted avg       0.98      0.98      0.98        60
#
# accuracy-score 0.9833333333333333
# Model score 0.9833333333333333

# %% [markdown]
# Prediction of species
#
# Here we can classify the three types of species of Iris flowers.

# %%
X_new = np.array([[3, 2, 1, 0.2, 1], [4.9, 2.2, 3.8, 1.1, 2], [5.3, 2.5, 4.6, 1.9, 3]])

#Prediction of the species
prediction = id3.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor']
# C:\Users\Prajakta\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
